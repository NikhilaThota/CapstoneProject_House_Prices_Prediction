# %% [markdown]
# # Import all the required libraries

# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
# inline statement - displays the graphs in the current notebook
% matplotlib inline

# %% [markdown]
# Let us load the modified csv file from the previous notebook **house_prices_cleaned.csv**

# %%
house_prices_new = pd.read_csv("E:\Data Science\Capstone Project - House prices\Data Story\\house_prices_cleaned.csv")

# %%
# Display first five rows of the dataframe
house_prices_new.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street            Alley  \
# 0   1          60       RL         65.0     8450   Pave  No alley access
# 1   2          20       RL         80.0     9600   Pave  No alley access
# 2   3          60       RL         68.0    11250   Pave  No alley access
# 3   4          70       RL         60.0     9550   Pave  No alley access
# 4   5          60       RL         84.0    14260   Pave  No alley access
#
#   LotShape LandContour Utilities    ...     PoolArea   PoolQC     Fence  \
# 0      Reg         Lvl    AllPub    ...            0  No Pool  No Fence
# 1      Reg         Lvl    AllPub    ...            0  No Pool  No Fence
# 2      IR1         Lvl    AllPub    ...            0  No Pool  No Fence
# 3      IR1         Lvl    AllPub    ...            0  No Pool  No Fence
# 4      IR1         Lvl    AllPub    ...            0  No Pool  No Fence
#
#   MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# **Check if house_prices_new has any null values**

# %%
house_prices_new.isnull().values.any()
# Out:
# False

# %% [markdown]
# describe() is a very useful fuction that is applicable to numerical data by default. It gives the minimum, maximum, no. of non nulls and useful statistics such as mean and standard deviation.

# %%
house_prices_new.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.205479   10516.828082     6.099315
# std     421.610009    42.300571    23.051007    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    60.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.500000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.586644   443.639726
# std       1.112799    30.202904     20.645407   180.728103   456.098091
# ...

# %% [markdown]
# # Divided the dataframe into - numerical and categorical

# %% [markdown]
# To keep things simple and easy let us split the dataframe into Numerical and Categorical and explore the data.

# %%
house_prices_new_numerical = house_prices_new.select_dtypes(include = [np.number])

# %%
house_prices_new_numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 38 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# LotFrontage      1460 non-null float64
# LotArea          1460 non-null int64
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# MasVnrArea       1460 non-null float64
# BsmtFinSF1       1460 non-null int64
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# ...

# %%
house_prices_new_numerical.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.205479   10516.828082     6.099315
# std     421.610009    42.300571    23.051007    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    60.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.500000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.586644   443.639726
# std       1.112799    30.202904     20.645407   180.728103   456.098091
# ...

# %% [markdown]
# Categorical variables - house_prices_new_categorical

# %%
house_prices_new_categorical = house_prices_new.select_dtypes(include = [object])

# %%
house_prices_new_categorical = house_prices_new_categorical.apply(lambda x: x.astype('category'))

# %%
house_prices_new_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 43 columns):
# MSZoning         1460 non-null category
# Street           1460 non-null category
# Alley            1460 non-null category
# LotShape         1460 non-null category
# LandContour      1460 non-null category
# Utilities        1460 non-null category
# LotConfig        1460 non-null category
# LandSlope        1460 non-null category
# Neighborhood     1460 non-null category
# Condition1       1460 non-null category
# Condition2       1460 non-null category
# BldgType         1460 non-null category
# HouseStyle       1460 non-null category
# RoofStyle        1460 non-null category
# RoofMatl         1460 non-null category
# Exterior1st      1460 non-null category
# Exterior2nd      1460 non-null category
# MasVnrType       1460 non-null category
# ExterQual        1460 non-null category
# ExterCond        1460 non-null category
# Foundation       1460 non-null category
# ...

# %% [markdown]
# describe() when applied to categorical data gives the unique classes/ categories present in each categorical feature (count), most repeated category (top) and the frequency of the occurance of the most repeated category (freq)

# %%
house_prices_new_categorical.describe()
# Out:
#        MSZoning Street            Alley LotShape LandContour Utilities  \
# count      1460   1460             1460     1460        1460      1460
# unique        5      2                3        4           4         2
# top          RL   Pave  No alley access      Reg         Lvl    AllPub
# freq       1151   1454             1369      925        1311      1459
#
#        LotConfig LandSlope Neighborhood Condition1      ...      GarageType  \
# count       1460      1460         1460       1460      ...            1460
# unique         5         3           25          9      ...               7
# top       Inside       Gtl        NAmes       Norm      ...          Attchd
# freq        1052      1382          225       1260      ...             870
#
#        GarageFinish GarageQual GarageCond PavedDrive   PoolQC     Fence  \
# count          1460       1460       1460       1460     1460      1460
# unique            4          6          6          3        4         5
# ...

# %% [markdown]
# Let us start exploring the numerical data first. I used Pearson correlation on resultant variable 'Sale Price' to find out the strongest correlated variables that effect the final sale price of the house

# %%
house_prices_new_numerical_corr = house_prices_new_numerical.corr(method='pearson')['SalePrice']

# %%
# Sort the features with the strongest correlated variable on th top
house_prices_new_numerical_corr[np.argsort(house_prices_new_numerical_corr, axis=0)[::-1]]
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.474279
# GarageYrBlt      0.467290
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# LotFrontage      0.310673
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %% [markdown]
# Top five variables that are strongly correlated with the target variable 'Sale Price'

# %%
house_prices_new_numerical_corr.sort_values(ascending = False).head(11)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %%
house_prices_new_numerical_topten = house_prices_new_numerical[['OverallQual','GrLivArea','GarageCars','GarageArea',
                                                                 'TotalBsmtSF','1stFlrSF', 'FullBath', 'TotRmsAbvGrd',
                                                                'YearBuilt', 'YearRemodAdd', 'SalePrice']]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# **Numerical data - EDA**

# %%
list(house_prices_new_numerical.columns.values)
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %% [markdown]
# I used **seaborn library** to represent my graphs.
#
# Let us explore more about the five important features in more detail. This can be made convinient through plotting pairplot in Seaborn. I introduced regression line to see how deep the correlaion is.

# %%
plt.figure(figsize=(20,6))
sns.set_style('white')
sns.set_style('ticks')
sns.pairplot(house_prices_new_numerical_topten, kind='reg')

# %% [markdown]
# From the graph above OverallQual is positively correlated with GrLivArea,GarageCars, GarageArea and TotalBsmtSF. We can clearly see that most of the top ten numerical features have strong correlation with the others.

# %% [markdown]
# **A heat map can be more interactive. Let us plot a heat map between the correlated variables**

# %%
corrmatrix = house_prices_new_numerical.corr()
k = 11 #number of variables for heatmap
cols = corrmatrix.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(house_prices_new_numerical[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, 
                 xticklabels=cols.values)
plt.show()

# %% [markdown]
# - Ah! Heatmap is the best way to get a quick overview of the relationships between varaibles. The correlation between the variables is so strong that it can indicate a situation of multicollinearity.
# - It is evident that there exists a strong relationship between **'GarageCars' and 'GarageArea', 'Total Basement square footage' and '1st floor square footage', 'Above grade(ground) area' and 'Total no. of rooms above grade(ground)**.
#
# A few other noticeable correlations are between:
# - OverallQual and Above ground area, Garage cars, Garage area, Year built
# - Above ground area and 1st floor, Full bath
# - Garage cars and OverallQual, Year built
# - Year built and Year remodeled

# %% [markdown]
# Let us explore the stringest correlated variables obtained from Heatmap

# %%
# GarageCars and GarageArea
plt.figure(figsize=(12,6))
sns.set_style('white')
sns.set_style('ticks')
g= sns.violinplot(x='GarageCars', y='GarageArea', data=house_prices_new_numerical)
g.set(xlabel='Garage car capacity', ylabel='Garage area(sqft)')

# %% [markdown]
# - The plot clearly shows a linear relationship between Garage car capacity and Garage area
# - Of course, it is obvious that bigger garages accommodate more cars, it is more evident with the violin plot above

# %%
# TotalBsmtSF and 1stFlrSF
sns.set_style('white')
sns.set_style('ticks')
g = sns.jointplot(x='TotalBsmtSF', y='1stFlrSF', data=house_prices_new_numerical)
g.set_axis_labels('Total Basement area(sqft)','1st floor(sqft)')

# %% [markdown]
# From the scatter plot above we can see that both the varibales are positively correlated. The more the area of basement, more the area of 1st floor

# %%
# GrLivArea and TotRmsAbvGrd
sns.set_style('white')
sns.set_style('ticks')
g= sns.barplot(x='TotRmsAbvGrd', y='GrLivArea', data=house_prices_new_numerical)
g.set(xlabel='Total rooms above ground', ylabel='mean(Above ground area(sqft))')

# %% [markdown]
# There is a strong correlation between Total rooms above ground and Above ground area (sqft). This might lead tp multicollinearity, we can overcome this issue by running machine learning algorithms.

# %% [markdown]
# Let us explore the correlation between each of the **top five** numerical variables in more detail
#
# **_Above Grade Area is the part of the dwelling that is above the ground line i.e. anything other than the basement_**

# %%
sns.set_style('white')
sns.set_style('ticks')
plt.figure(figsize=(12,6))
g = sns.boxplot(x='OverallQual', y='GrLivArea', data=house_prices_new_numerical)
g.set(xlabel='House Quality', ylabel='Above grade area (sqft)')

# %% [markdown]
# - Minimum Ground living area of a house ranging from quality 3-10 is 1000 sqft
# - From the boxplot it is evident that Overall Quality of the house and Ground Living Area are positively correlated. The better the house quality the more the Ground Living Area. Also from the median of each box plot we can say that the 'average Ground Living Area' increases with increase in quality

# %%
sns.set_style('white')
sns.set_style('ticks')
g= sns.barplot(x='OverallQual', y='GarageCars', data=house_prices_new_numerical)
g.set(xlabel='House Quality', ylabel='mean(Garage - car capacity)')

# %% [markdown]
# - From the bar plot we can say that Overall Quality and Garage cars are positively correlated.
# - High quality houses can accommodate more number of cars in garage (obviously garage area is bigger)

# %%
plt.figure(figsize=(12,6))
sns.set_style('white')
sns.set_style('ticks')
g = sns.violinplot(x='OverallQual', y='GarageArea', data=house_prices_new_numerical)
g.set(xlabel='House Quality', ylabel='Garage Area (sqft)')

# %% [markdown]
# - There are a few houses with no garages.
# - All the houses ranked above 5 (house quality) have mimium Garage Area with 100 sqft
# - Also on an average high quality houses have larger garage areas

# %%
sns.set_style('white')
sns.set_style('ticks')
p = sns.barplot(x='OverallQual', y='TotalBsmtSF', data=house_prices_new_numerical)
p.set(xlabel='House Quality', ylabel='mean(Basement area(sqft))')

# %% [markdown]
# - Basement areas range from 300 sqft to 2700 sqft
# - Overall Quality and Basement area show linear corelation, good quality houses have larger basement

# %%
plt.figure(figsize=(12,6))
sns.set_style('white')
sns.set_style('ticks')
p= sns.boxplot(x='GarageCars', y='GrLivArea', data=house_prices_new_numerical)
p.set(xlabel='Garage car capacity', ylabel='Above grade area')

# %% [markdown]
# Inference from the graph above - greater the garage capacity, there's an increase in the Above grade area (top/ 1st floor)

# %%
sns.set_style('white')
sns.set_style('ticks')
g = sns.jointplot(x='GarageArea', y='GrLivArea', data=house_prices_new_numerical)
g.set_axis_labels('Garage Area(sqft)','Above grade area(sqft)')

# %% [markdown]
# - There seems to be a positive correlation between Garage area and Above grade area. If a house has bigger garage then the top floor/s have are bigger in area too
# - Garage area, garage car capacity are both positively corelated to Above grade area

# %%
sns.set_style('white')
sns.set_style('ticks')
g = sns.jointplot(x='GrLivArea', y='TotalBsmtSF', data=house_prices_new_numerical)
g.set_axis_labels('Above grade area(sqft)','Basement area(sqft)')

# %% [markdown]
# - Ground Living Area and Total Basement are positively correlated.
# - The scatter plot shows thay houses with bigger Basement area also have bigger Ground living area

# %%
sns.set_style('white')
sns.set_style('ticks')
sns.jointplot(x='GarageCars', y='TotalBsmtSF', data=house_prices_new_numerical)

# %% [markdown]
# - There is not much to talk about Garage car capacity and Basment area.
# - There is no relation between them.

# %%
sns.set_style('white')
sns.set_style('ticks')
g= sns.jointplot(x='GarageArea', y='TotalBsmtSF', data=house_prices_new_numerical)
g.set_axis_labels('Garage car capacity','Basement area(sqft)')

# %% [markdown]
# - Clearly garage area and total basement area are positively correlated
# - Houses with bigger garages also have bigger basements

# %% [markdown]
#  # Categorical data - EDA

# %% [markdown]
# I would like to explore the relationship between all categorical varibales with the output variable i.e. Sale Price

# %%
list(house_prices_new_categorical.columns.values)
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
plt.figure(figsize = (15, 6))
c = sns.boxplot(x='MSZoning', y='SalePrice', data=house_prices_new)
c.set(xlabel='Zone', ylabel='SalePrice($)')
c.legend(['RL- Residential Low Density','RM- Residential Medium Density','C- Commercial','FV- Floating Village Residential',
               'RH- Residential High Density'], title='Zone')

# %% [markdown]
# From the boxplot above:
#
# - Floating village residences and Residential low density are expensive compared to others.
# - Residential low density zone houses are more in number, it also has many outliers, On an average they range between \$130,000 to \$230,000
#
# - Clearly there is no pattern between zones and final sale price

# %%
sns.countplot(x='Street', data=house_prices_new)

# %% [markdown]
# There are a very few columns (hardly 5) with category Gravel. This varible might not have an effect on Sale Price

# %%
plt.figure(figsize = (12,6))
g = sns.barplot(x='LotShape', y='SalePrice', data=house_prices_new)
g.set(ylabel='mean(SalePrice($))')
g.legend(['Regular','Slightly irregular','Moderately Irregular','Irregular'])

# %% [markdown]
# It appears that Regular lot shapes are least expensive. Irregular shaped lots are comparitively higher, but looks like if the lot has too many flaws they are priced lesser than moderately irregular plots.

# %%
plt.figure(figsize=(12,6))
g = sns.violinplot(x='LandContour', y='SalePrice',data=house_prices_new)
g.set(xlabel='Lot flatness', ylabel='SalePrice($)')
g.legend(['Lvl- Near Flat','Bnk- Slope from street to building','Low- Depression','HLS- Slope from side to side'], 
         title='Lot flatness')

# %% [markdown]
# Lots with low flatness and slopes to the sides (lot) tend to be higher in price.
# Though flat lots mostly range between \$100,000 - \$200,000 it cocnsists of houses priced at $700,000 (these can be considered outliers)

# %%
sns.countplot(x='Utilities', data=house_prices_new)

# %% [markdown]
# There is only one house with no sewage and water. The other houses have all basic utilities (Electricity, Gas, Water, Sewage)

# %%
plt.figure(figsize=(10,6))
g = sns.barplot(x='LotConfig', y='SalePrice', data=house_prices_new)
g.set(xlabel='Lot configuration', ylabel='mean(SalePrice($))')
g.legend(['Inside- Inside lot','FR2- Frontage on 2 sides of property','Corner- Corner lot','CulDSac- Cul-de-sac',
          'FR3- Frontage on 3 sides of property'],title='Lot configuration')

# %% [markdown]
# - Inside lots and Corner lots are priced almost equally with a mean price of $170,000
#
# - Cul-de-sac houses tend to have the highest average price of about $230,000

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x='LandContour', y='SalePrice', hue='LandSlope', data=house_prices_new)
g.set(xlabel='Lot flatness', ylabel='mean(SalePrice($))')
#'Lvl- Near Flat','Bnk- Slope from street to building','Low- Depression','HLS- Slope from side to side

# %% [markdown]
# Slope from side to side (HLS) seems that a house is sloped from one side to the other, which probably means that the house might be on a hill. Therefore we can conclude that a hill side house/ a house at higher elevation is highly priced.

# %%
plt.figure(figsize=(20,6))
sns.boxplot(x='Neighborhood', y='SalePrice', data=house_prices_new)

# %% [markdown]
# - Lowest price range neighborhoods are Mitchell,  Brookside, Sawyer, Iowa DOT and Rail Road, Meadow Village, and Briardale
# - Neighborhods like College Creek, Veenker, Crawford, Somerset, Northwest Ames, Sawyer West, Timberland, Clear Creek, Bloomington Heights have houses ranging anywhere between \$100,000 - \$350,000 USD (not considering the outliers)
# - Northridge, Northridge Heights, Stone Brook seem to have high end houses. Most of the houses range from \$250,000 - \$350,000 and can go upto $75,000 for a few upscale houses.

# %%
plt.figure(figsize=(12,6))
g = sns.violinplot(x='BldgType', y='SalePrice',data=house_prices_new)
g.set(xlabel='Building Type', ylabel='SalePrice($)')
g.legend(['1Fam- Single-family Detached','2FmCon- Two-family Conversion','Duplx- Duplex','TwnhsE- Townhouse End Unit',
          'TwnhsI- Townhouse Inside Unit'], title='Building Type')

# %% [markdown]
# - Most of the houses fall under Single family or end unit town house, and the sale price for the both ranges from \$50,000 - \$300,000, ignoring the outliers.
# Others settle for duplex, two family conversion or Inside unit town home, which have an avarage sale price ranging from \$100,000 - \$200,000

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x='HouseStyle', y='SalePrice', hue='BldgType',data=house_prices_new)
g.set(ylabel='mean(SalePrice($)')
#'1Fam- Single-family Detached','2FmCon- Two-family Conversion','Duplx- Duplex','TwnhsE- Townhouse End Unit',
         # 'TwnhsI- Townhouse Inside Unit

# %%
g= sns.factorplot(x='RoofStyle', y='SalePrice', hue='RoofMatl', data=house_prices_new,size=6)
g.set(ylabel='SalePrice($)')
#'CompShg- Standard Composite Shingle','WdShngl- Wood Shingles','WdShake- Wood Shakes','Membran- Membrane',
          #'Tar&Grv- Gravel & Tar','ClyTile	Clay or Tile'

# %%
plt.figure(figsize=(12,6))
g = sns.violinplot(x='MasVnrType', y='SalePrice',data=house_prices_new)
g.set(xlabel='Masonry veneer type', ylabel='SalePrice($)')
g.legend(['BrkFace- Brick Face','BrkCmn- Brick Common'], title='Masonry veneer type')

# %% [markdown]
# Face brick and Common brick both range between 100,000 USD to 300,000 USD, with majority of the houses priced at approximately $180,000.

# %%
plt.figure(figsize=(10,6))
g= sns.barplot(x='ExterCond', y='SalePrice', data=house_prices_new)
g.set(xlabel='Exterior material condition', ylabel='mean(SalePrice($))')
g.legend(['TA- Average/Typical','Gd- Good','Fa- Fair','Po- Poor','Ex- Excellent'],title= 'Exterior material condition')

# %% [markdown]
# We can infer that exterior condition with Average and above average rating are priced at $180,000 approximately. This also tells us we can reduce the categories to Good and Poor instead of having five different categories

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x='BsmtCond', y='SalePrice', data=house_prices_new)
g.set(xlabel='Basement Condition', ylabel='mean(Sale Price($))')
g.legend(['Gd- Good','TA- Typical/Average','Fa- Fair','Po- Poor'],title='Basement Condition')

# %% [markdown]
# - Houses with Basement are priced more than houses without basement.
# - Basement condition and Saleprice have linear correlation.

# %%
plt.figure(figsize=(10,6))
g = sns.boxplot(x='HeatingQC', y='SalePrice', data=house_prices_new)
g.set(xlabel='Heating Quality', ylabel='Sale Price($)')
g.legend(['Ex- Excellent','Gd- Good','TA- Typical/Average','Fa- Fair','Po- Poor'],title='Heating Quality')

# %% [markdown]
# Houses with good heating system are highly priced. We can infer that Heating condition and Saleprice are positively correlated

# %%
plt.figure(figsize=(6,6))
g = sns.boxplot(x='CentralAir', y='SalePrice', data=house_prices_new)
g.set(xlabel='Central AC', ylabel='Sale Price ($)')

# %% [markdown]
# Just like the heating system, there exists a linear correlation between Centralized AC and Sale price of a house.

# %%
plt.figure(figsize=(12,6))
g = sns.boxplot(x='Electrical', y='SalePrice', data=house_prices_new)
g.set(xlabel='Electrical system', ylabel='Sale Price ($)')
g.legend(['SBrkr- Standard Circuit Breakers & Romex','FuseA- Average wiring','FuseF- Fair wiring',
          'FuseP- Poor wiring','Mix- Mixed'],title='Electrical system')

# %% [markdown]
# Standard wiring seems to be most acceptable for any house. From the violin plot the fair wiring houses are slightly priced more than the average and poor wiring.

# %%
plt.figure(figsize=(12,6))
g=sns.violinplot(x='KitchenQual', y='SalePrice', data=house_prices_new)
g.set(xlabel='Kitchen Quality', ylabel='Sale Price($)')
g.legend(['Ex- Excellent','Gd- Good','TA- Typical/Average','Fa- Fair'], title='Kitchen Quality')

# %% [markdown]
# From the graph it is evident that houses Good and Excellent quality kitchens are priced more. Therefore Kitchen Quality and Saleprice are positively corelated.

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x='GarageType', y='SalePrice', hue='GarageQual', data=house_prices_new)
g.set(xlabel='Garage location', ylabel='SalePrice($)')
#g.legend(['Ex- Excellent','Gd- Good','TA- Typical/Average','Fa- Fair','Po- Poor','NA- No Garage'], title='Garage Quality')

# %% [markdown]
# - Looks like 'Attached', 'Detached' and 'Builtin' garages are more common among most of the houses, among which Builtin garages with good condition are priced more than any other.
# - In conclusion houses with good and excellent garages which are either attached, detached or builtin are high priced.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='SaleType', y='SalePrice', data=house_prices_new)
g.legend(['WD- Conventional Warranty Deed','CWD- Cash Warranty Deed','VWD- VA Loan Warranty Deed',
          'New- New construction','COD- Court Officer Deed/Estate','Con- Contract 15% Down payment',
          'ConLw- Contract Low Down payment and low interest','ConLI- Contract Low Interest','ConLD- Contract Low Down',
          'Oth- Other'], title='Sale Type')

# %% [markdown]
# Newly constructed and 15% down paymemt with normal interest rates houses seem to be highly priced. All the others are under $200,000

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x='SaleCondition', y='SalePrice', data=house_prices_new)
g.legend(['Normal- Normal Sale','Abnorml- trade, foreclosure, short sale','AdjLand- Adjoining Land Purchase',
          'Alloca- typically condo with a garage unit','Family- Sale between family members',
          'Partial- Partial built house'], title='Sale Condition')

# %% [markdown]
# Seems like there is no trend between Sale condition and Sale price. Apparantly partially built houses are priced more than normal houses.
